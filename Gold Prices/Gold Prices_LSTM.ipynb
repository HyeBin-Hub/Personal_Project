# %%
import pandas as pd

df_monthly=pd.read_csv("./data/monthly_csv.csv")

# 시계열 자료를 년도와 월로 나눠 시간 순으로 정렬
df_monthly['Year'] = pd.DatetimeIndex(df_monthly['Date']).year
df_monthly['Month'] = pd.DatetimeIndex(df_monthly['Date']).month
df_monthly.set_index(["Date"])
# Out:
#             Price  Year  Month
# Date
# 1950-01    34.730  1950      1
# 1950-02    34.730  1950      2
# 1950-03    34.730  1950      3
# 1950-04    34.730  1950      4
# 1950-05    34.730  1950      5
# ...           ...   ...    ...
# 2020-03  1593.764  2020      3
# 2020-04  1680.030  2020      4
# 2020-05  1715.697  2020      5
# 2020-06  1734.032  2020      6
# 2020-07  1840.807  2020      7
#
# [847 rows x 3 columns]

# %%
df_annual=pd.read_csv("./data/annual_csv.csv")

# 시계열 자료를 년도와 월로 나눠 시간 순으로 정렬
df_annual['Year'] = pd.DatetimeIndex(df_annual['Date']).year
df_annual['Month'] = pd.DatetimeIndex(df_annual['Date']).month
df_annual.set_index(["Date"])

import matplotlib.pyplot as plt

# 연간 금 가격 추세 시각화
fig,axes=plt.subplots(figsize=(15,5))

x=df_annual['Year']
y=df_annual['Price']

plt.plot(x,y)
plt.tick_params(labelcolor="white")
plt.title("Visualize gold price trends by year.",color="#fff",fontsize =20,pad=20)
plt.legend(df_annual["Month"],loc=2,fontsize =15)
plt.show()

# %%
import matplotlib.pyplot as plt

# 월별 5 년주기 금 가격 시각화 
fig,axes=plt.subplots(figsize=(20,10))
arr=[]
for i in range(1950,2021,5):
    a=df_monthly[df_monthly["Year"]==i]
    x=a["Month"]
    y=a["Price"]
    axes.plot(x,y)
    arr.append(i)
    
axes.set_xticks(range(1,13))    
axes.set_xticklabels(axes.get_xticks(),size=20)
axes.set_yticklabels(axes.get_yticks(),size=20)
axes.legend(arr,bbox_to_anchor=(1.1, 0.5), loc='right',fontsize =15)
axes.set_title("Visualize monthly 5-year cycle gold prices",fontsize =30,pad=30)
# Out:
# <ipython-input-23-6dc3eed40b41>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_yticklabels(axes.get_yticks(),size=20)
# Text(0.5, 1.0, 'Visualize monthly 5-year cycle gold prices')

# %%
#print(df_annual["Price"].max())
#print(df_annual["Price"].min())
#print(len(df_annual["Price"]))

# %%
# 임의의 범위를 정해 train/test data를 분리해주었다.
import numpy as np

price=df_monthly["Price"].to_numpy()

train_x=[]
train_y=[]

for i in range(price.shape[0]-9):
    #print(price[i:i+9])
    train_x.append(price[i:i+9])
    #print(price[i+9])
    train_y.append(price[i+9])
    
train_x=np.array(train_x)
train_y=np.array(train_y)
train_x=np.reshape(train_x,(-1,9,1))
print(train_x.shape,train_y.shape)
print(test_x.shape,test_y.shape)
# Out:
# (838, 9, 1) (838,)
# (669,) (168,)

# %%
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y=train_test_split(train_x,train_y,test_size=0.2)
print(train_x.shape,train_y.shape)
print(test_x.shape,test_y.shape)
# Out:
# (670, 9, 1) (670,)
# (168, 9, 1) (168,)

# %%
train_x.shape
# Out:
# (837, 9, 1)

# %%
train_y.shape
# Out:
# (837,)

# %% [markdown]
# LSTM(Long Short -Trem Memory)
# - 현제 입력 데이터와 이전 타임스텝의 단기 상태를 분석하는 역할을 한다
# - 기본 RNN은 BPTT에서 기울기의 손실 혹은 폭발이 일어나 장기 의존 관계를 학습하기 어려운 문제점이 있었다 .이 문제점을 보완하기 위해 LSTM이 나왔다
#     <img src="./image/LSTM.png" height="500px" width="700px" >
# - 기본 RNN과 다르게 LSTM계층에는 c(memory cell, 기억 셀)이 있다
# - c(memory cell, 기억 셀)
#     - LSTM의 기억 메거니즘이다
#     - c(t)는 과거로 부터 현재의 timestep까지의 필요한 모든 정보가 들어있다고 가정한다.
#     - 출력하는 h(t)는 기억 셀의 값을 tanh함수로 변환한 값이다
#     - c(t)와 h(t)의 원소 수는 같다
#     <img src="./image/cell state.png" height="500px" width="700px" >
# - 게이트
#     - LSTM에서 사용하는 게이트는 열기/닫기, 어느 정도 열지를 조절한다
#       (게이트를 얼마나 열지는 데이터로부터(자동적으로) 학습한다)
#     - 게이트의 열림상태(어느 정도)는 0.0 ~ 1.0 사이의 실수로 나타낸다
#       그래서 게이트의 열림상태를 구할때는 시그모이드 함수를 사용한다
#       (시그모이드 함수의 출력은 0.0 ~ 1.0사이의 실수이다)
#     - 게이터의 열림상태를 제어하기 위해 전용 가중치 매개변수를 이용하며, 이 가중치 매개변수는 학습데이터로부터 갱신된다
#     1. output gate
#         - 다음 은닉 상태 h(t)의 출력을 담당하는 게이트
#         - 열린 상태(어느 정도 보낼지)는 입력 x(t)와 이전 상태 h(t)로부터 구한다
#     <img src="./image/output gate.png" height="500px" width="700px" >
#
#         - tanh의 출력 : -1.0 ~ 1.0의 실수
#             - 이 수치를 그 안에 인코딩된 정보의 강약(정도)을 표시한다고 해석한다
#             - 실질적인 정보를 지니는 데이터에 활성화 함수로 tanh를 사용한다
#         - sigmoid의 출력 : 0.0 ~ 1.0의 실수
#             - 데이터를 얼마만큼 통과 시킬지를 결정하는 비율
#             - 게아트에서 사용하는 활성화 함수이다
#     2. forget gate
#         - c(t-1)의 기억 중에서 불필요한 기억을 잊게하기 위한 게이트
#         <img src="./image/forget gate.png" height="500px" width="700px" >
#     * tanh 노드 추가하여 새롭게 기억할 셀 추가
#         - c(t)에 새로운 정보가 추가된다
#         - tanh 노드는 게이트가 아니며, 새로운 정보를 기억 셀에 추가하기 위해 사용한다
#     3. input gate
#         - 새롭게 추가된 정보의 가치가 얼마나 큰지 판단하기 위한 게이트
#         - 아무렇게나 정보를 업데이트하는게 아니라 적절한 정보인지 판단하는 것이 이 게이트의 역할\
#         <img src="./image/input gate.png" height="500px" width="700px" >

# %%
import tensorflow as tf

# 모델 생성
inputs=tf.keras.Input(shape=(9,1),name="input")

# 기억 셀(cell state)과 hidden state에 대한 출력을 바꾸는 변수 -> return_sequences, return_state 인자

# return_sequences : hidden state를 출력할 것인지에 대한 값
# return_sequences = False => one-to-many(마지막 hidden state만 출력, 기본값)
# return-sequences = True => many-to-many(hidden state 다 출력)

# return_state : cell state를 출력할 것인지에 대한 값
# return_stste = False => return_sequences가 False라면 마지막 hidden state만 출력, 기본값
#                         return_sequences가 True라면 hidden state 다 출력
# return_state = True => return_sequences가 False라면 hidden state와 cell state가 출력
#                        return_sequences가 True라면 hidden state 전체와 cell state가 출력

# 즉, return_squences, return_state 둘다 false라면 마지막 hidden state만 출력되고
#     return_squences, return_state 둘다 ture라면 hidden state 전체와 cell state가 출력된다

lstw1=tf.keras.layers.LSTM(6,return_sequences=True)(inputs)
# 여러 층을 쌓아 더 복잡한 패턴을 학습할 수 있게한다(정확도가 높아질 수 있다)
lstw2=tf.keras.layers.LSTM(6)(lstw1)
di=tf.keras.layers.Dense(6,activation="relu")(lstw2)
outputs=tf.keras.layers.Dense(1)(di)

model=tf.keras.Model(inputs=inputs,outputs=outputs)  

# 모델 학습과정 설정 
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
             loss=tf.keras.losses.MeanSquaredError(),
             metrics=["mse"])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 9, 1)]            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 9, 6)              192
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 6)                 312
# _________________________________________________________________
# dense (Dense)                (None, 6)                 42
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.fit은 model.compile에서 지정한 방식으로 학습을 진행함 
# compile에서 정한 metrics를 반환하여, 기록을 살펴봄 
# fit(X(Numpy array 또는 TensorFlow tensor),Y(Numpy 어레이 또는 TensorFlow 텐서),epochs,batch_size)
model.fit(train_x,train_y,epochs=15,batch_size=100)
# Out:
# Epoch 1/15
# 9/9 [==============================] - 7s 6ms/step - loss: 384791.4938 - mse: 384791.4938
# Epoch 2/15
# 9/9 [==============================] - 0s 6ms/step - loss: 392244.9813 - mse: 392244.9813
# Epoch 3/15
# 9/9 [==============================] - 0s 5ms/step - loss: 354865.7687 - mse: 354865.7687
# Epoch 4/15
# 9/9 [==============================] - 0s 5ms/step - loss: 367089.9469 - mse: 367089.9469
# Epoch 5/15
# 9/9 [==============================] - 0s 5ms/step - loss: 370529.5062 - mse: 370529.5312
# Epoch 6/15
# 9/9 [==============================] - 0s 5ms/step - loss: 375366.6969 - mse: 375366.7250
# Epoch 7/15
# 9/9 [==============================] - 0s 5ms/step - loss: 354449.5781 - mse: 354449.5750
# Epoch 8/15
# 9/9 [==============================] - 0s 5ms/step - loss: 339170.0812 - mse: 339170.0812
# Epoch 9/15
# 9/9 [==============================] - 0s 5ms/step - loss: 353759.2938 - mse: 353759.2938
# Epoch 10/15
# 9/9 [==============================] - 0s 5ms/step - loss: 333818.4500 - mse: 333818.4500
# Epoch 11/15
# 9/9 [==============================] - 0s 6ms/step - loss: 351163.1031 - mse: 351163.1125
# Epoch 12/15
# 9/9 [==============================] - 0s 5ms/step - loss: 371043.7719 - mse: 371043.7719
# Epoch 13/15
# 9/9 [==============================] - 0s 5ms/step - loss: 304437.5578 - mse: 304437.5578
# Epoch 14/15
# 9/9 [==============================] - 0s 5ms/step - loss: 329425.9594 - mse: 329425.9594
# Epoch 15/15
# 9/9 [==============================] - 0s 5ms/step - loss: 333918.8094 - mse: 333918.8094

# %%
# predict(X(Numpy array 또는 TensorFlow tensor))
model.predict(np.reshape(test_x,(-1,9,1)))
# Out:
# array([[86.05975]], dtype=float32)

# %%
# https://wegonnamakeit.tistory.com/7
# https://dgkim5360.tistory.com/entry/understanding-long-short-term-memory-lstm-kr \
# 밑바닥부터 시작하는 딥러닝1, 2
